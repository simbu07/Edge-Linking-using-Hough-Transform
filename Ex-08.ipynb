# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 125.1 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
#      ------------------------------------ 163.0/163.0 kB 574.2 kB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 126.3 kB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#      --------------------------------------- 55.4/55.4 kB 85.0 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\simbu\anconda\envs\imageproc\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\simbu\anconda\envs\imageproc\lib\site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 56.6 kB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      --------------------------------------- 98.3/98.3 kB 56.4 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\simbu\anconda\envs\imageproc\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\simbu\anconda\envs\imageproc\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.3 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
image = cv2.imread("esrageziyor.jpg",0)
img = cv2.GaussianBlur(image,(3,3),0)
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
edge = cv2.Canny(img,50,100)
plt.imshow(edge,cmap='gray')
plt.title('Edged Image after applying Canny Edge Detector')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
lines=cv2.HoughLinesP(edge,1,np.pi/180, threshold=80, minLineLength=50,maxLineGap=250)

# %%
for line in lines:
    x1,y1,x2,y2 = line[0]
    cv2.line(edge,(x1,y1),(x2,y2),(250,0,0),3)

# %%
plt.imshow(edge)
plt.axis('off')
plt.show()
